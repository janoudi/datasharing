# %% [markdown]
# <a href="https://colab.research.google.com/github/janoudi/datasharing/blob/master/Veeva_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd

# %% [markdown]
# Scenario analysis for Veeva EDC. First cell represent fixed values. Initial values reflect the Veeva proposal

# %%
patient_block = 300
block_duration_days = 61
block_duration_months = 3
first_tier = 100
second_tier = 200
third_tier = 300
cost_first_tier = 50
cost_second_tier = 40
cost_third_tier = 35
cost_passive = 5
cap_per_block = 10000
cap_per_month = 25000
base_cost_per_month = 2000
days_per_month = 30
build_cost = 2000

# %% [markdown]
# Input parameters. The two factors that will drive the overall costs are study duration and total number of patients enrolled. While our perpetual trials do not have either pre-planned, a scenario analysis can offer infomation about costs.

# %%
study_expected_duration_month = 24
total_number_patients = 6000

# %% [markdown]
# Study overall charactersitcs based on input paramaters

# %%
enrolled_per_day = total_number_patients / (study_expected_duration_month * days_per_month)
enrolled_per_month = total_number_patients / study_expected_duration_month
days_to_block_size = patient_block / enrolled_per_day
months_to_block_size = patient_block / enrolled_per_month
days_to_block_passive = days_to_block_size + block_duration_days
months_to_block_passive = months_to_block_size + block_duration_months
total_number_blocks = total_number_patients / patient_block

# %% [markdown]
# Defining a function to calculate the cost of an active patient block based on the tier system and the cap. Note to self - base cost should be calcualted here

# %%
def active_pateints_total_cost (active_patients_n, first_tier_n = first_tier, second_tier_n = second_tier, third_tier_n = third_tier, first_tier_cost = cost_first_tier, second_tier_cost = cost_second_tier, third_tier_cost = cost_third_tier, base_cost = base_cost_per_month):
  if active_patients_n < first_tier_n:
    cost_for_active_patients = active_patients_n * first_tier_cost
    if cost_for_active_patients + base_cost < cap_per_block:
      return cost_for_active_patients + base_cost
    else:
      return cap_per_block
  elif active_patients_n < second_tier_n:
    cost_for_active_patients = active_patients_n * second_tier_cost
    if cost_for_active_patients + base_cost < cap_per_block:
      return cost_for_active_patients + base_cost
    else:
      return cap_per_block
  elif active_patients_n <= third_tier_n:
    cost_for_active_patients = active_patients_n * third_tier_cost
    if cost_for_active_patients + base_cost < cap_per_block:
      return cost_for_active_patients + base_cost
    else:
      return cap_per_block
  else:
    return "Error: number of active patients is invalid"

# %% [markdown]
# Loop to calculate per-month costs

# %%
per_month_patients = []
per_month_cost = []
month = []
per_month_info = {}
n = 1
while n <= study_expected_duration_month:
  new_patients = enrolled_per_month
  if len(per_month_patients) > 0:
    old_patients = per_month_patients[(n-2)]
  else:
    old_patients = 0
  all_patients = new_patients + old_patients
  per_month_patients.append(all_patients)
  number_of_completed_blocks = int(all_patients / patient_block) 
  if number_of_completed_blocks <= 1:
    number_of_passive_blocks = int(n / months_to_block_passive)
  else:
    number_of_passive_blocks = int((n - block_duration_months)/ months_to_block_size)  
  number_of_completed_active_blocks = number_of_completed_blocks - number_of_passive_blocks
  number_of_active_patients_not_in_block = all_patients - (number_of_completed_blocks * patient_block)
  if number_of_active_patients_not_in_block > 0:
    cost_for_active_patients_not_in_block = active_pateints_total_cost(number_of_active_patients_not_in_block)
  else:
    cost_for_active_patients_not_in_block = 0
  cost_for_active_blocks = number_of_completed_active_blocks * cap_per_block
  cost_for_passive_patients = number_of_passive_blocks * patient_block * cost_passive
  total_costs_per_month = cost_for_active_patients_not_in_block + cost_for_active_blocks + cost_for_passive_patients
  if total_costs_per_month < cap_per_month:
    monthly_total = total_costs_per_month
    per_month_cost.append(total_costs_per_month)
  else:
    monthly_total = cap_per_month
    per_month_cost.append(cap_per_month)
  month.append(n)
  per_month_info[n] = {
      'number of new patients': new_patients,
      'number of old patients': old_patients,
      'total number of patients': all_patients,
      'number of completed blocks': number_of_completed_blocks,
      'number of passive block': number_of_passive_blocks,
      'number of completed active blocks': number_of_completed_active_blocks,
      'number of active patients not in a completed block' : number_of_active_patients_not_in_block,
      'number of passive patients': number_of_passive_blocks,
      'cost for active patients not in a block': cost_for_active_patients_not_in_block,
      'cost for active blocks': cost_for_active_blocks,
      'cost for passive patients': cost_for_passive_patients,
      'total cost for the month': monthly_total
  }
  n = n + 1

# %%
print(sum(per_month_cost))
# Out:
# 579000.0

# %%
print(per_month_info)
# Out:
# {1: {'number of new patients': 250.0, 'number of old patients': 0, 'total number of patients': 250.0, 'number of completed blocks': 0, 'number of passive block': 0, 'number of completed active blocks': 0, 'number of active patients not in a completed block': 250.0, 'number of passive patients': 0, 'cost for active patients not in a block': 10000, 'cost for active blocks': 0, 'cost for passive patients': 0, 'total cost for the month': 10000}, 2: {'number of new patients': 250.0, 'number of old patients': 250.0, 'total number of patients': 500.0, 'number of completed blocks': 1, 'number of passive block': 0, 'number of completed active blocks': 1, 'number of active patients not in a completed block': 200.0, 'number of passive patients': 0, 'cost for active patients not in a block': 9000.0, 'cost for active blocks': 10000, 'cost for passive patients': 0, 'total cost for the month': 19000.0}, 3: {'number of new patients': 250.0, 'number of old patients': 500.0, 'total number of patients': 750.0, 'number of completed blocks': 2, 'number of passive block': 0, 'number of completed active blocks': 2, 'number of active patients not in a completed block': 150.0, 'number of passive patients': 0, 'cost for active patients not in a block': 8000.0, 'cost for active blocks': 20000, 'cost for passive patients': 0, 'total cost for the month': 25000}, 4: {'number of new patients': 250.0, 'number of old patients': 750.0, 'total number of patients': 1000.0, 'number of completed blocks': 3, 'number of passive block': 0, 'number of completed active blocks': 3, 'number of active patients not in a completed block': 100.0, 'number of passive patients': 0, 'cost for active patients not in a block': 6000.0, 'cost for active blocks': 30000, 'cost for passive patients': 0, 'total cost for the month': 25000}, 5: {'number of new patients': 250.0, 'number of old patients': 1000.0, 'total number of patients': 1250.0, 'number of completed blocks': 4, 'number of passive block': 1, 'number of completed active blocks': 3, 'number of active patients not in a completed block': 50.0, 'number of passive patients': 1, 'cost for active patients not in a block': 4500.0, 'cost for active blocks': 30000, 'cost for passive patients': 1500, 'total cost for the month': 25000}, 6: {'number of new patients': 250.0, 'number of old patients': 1250.0, 'total number of patients': 1500.0, 'number of completed blocks': 5, 'number of passive block': 2, 'number of completed active blocks': 3, 'number of active patients not in a completed block': 0.0, 'number of passive patients': 2, 'cost for active patients not in a block': 0, 'cost for active blocks': 30000, 'cost for passive patients': 3000, 'total cost for the month': 25000}, 7: {'number of new patients': 250.0, 'number of old patients': 1500.0, 'total number of patients': 1750.0, 'number of completed blocks': 5, 'number of passive block': 3, 'number of completed active blocks': 2, 'number of active patients not in a completed block': 250.0, 'number of passive patients': 3, 'cost for active patients not in a block': 10000, 'cost for active blocks': 20000, 'cost for passive patients': 4500, 'total cost for the month': 25000}, 8: {'number of new patients': 250.0, 'number of old patients': 1750.0, 'total number of patients': 2000.0, 'number of completed blocks': 6, 'number of passive block': 4, 'number of completed active blocks': 2, 'number of active patients not in a completed block': 200.0, 'number of passive patients': 4, 'cost for active patients not in a block': 9000.0, 'cost for active blocks': 20000, 'cost for passive patients': 6000, 'total cost for the month': 25000}, 9: {'number of new patients': 250.0, 'number of old patients': 2000.0, 'total number of patients': 2250.0, 'number of completed blocks': 7, 'number of passive block': 5, 'number of completed active blocks': 2, 'number of active patients not in a completed block': 150.0, 'number of passive patients': 5, 'cost for active patients not in a block': 8000.0, 'cost f ...

# %%
df = pd.DataFrame(per_month_info)

# %%
df
# Out:
#                                                          1        2        3   \
# number of new patients                                250.0    250.0    250.0
# number of old patients                                  0.0    250.0    500.0
# total number of patients                              250.0    500.0    750.0
# number of completed blocks                              0.0      1.0      2.0
# number of passive block                                 0.0      0.0      0.0
# number of completed active blocks                       0.0      1.0      2.0
# number of active patients not in a completed block    250.0    200.0    150.0
# number of passive patients                              0.0      0.0      0.0
# cost for active patients not in a block             10000.0   9000.0   8000.0
# cost for active blocks                                  0.0  10000.0  20000.0
# cost for passive patients                               0.0      0.0      0.0
# total cost for the month                            10000.0  19000.0  25000.0
#
#                                                          4        5        6   \
# number of new patients                                250.0    250.0    250.0
# number of old patients                                750.0   1000.0   1250.0
# total number of patients                             1000.0   1250.0   1500.0
# number of completed blocks                              3.0      4.0      5.0
# number of passive block                                 0.0      1.0      2.0
# number of completed active blocks                       3.0      3.0      3.0
# number of active patients not in a completed block    100.0     50.0      0.0
# number of passive patients                              0.0      1.0      2.0
# cost for active patients not in a block              6000.0   4500.0      0.0
# cost for active blocks                              30000.0  30000.0  30000.0
# cost for passive patients                               0.0   1500.0   3000.0
# total cost for the month                            25000.0  25000.0  25000.0
#
#                                                          7        8        9   \
# number of new patients                                250.0    250.0    250.0
# number of old patients                               1500.0   1750.0   2000.0
# total number of patients                             1750.0   2000.0   2250.0
# number of completed blocks                              5.0      6.0      7.0
# number of passive block                                 3.0      4.0      5.0
# number of completed active blocks                       2.0      2.0      2.0
# number of active patients not in a completed block    250.0    200.0    150.0
# number of passive patients                              3.0      4.0      5.0
# cost for active patients not in a block             10000.0   9000.0   8000.0
# cost for active blocks                              20000.0  20000.0  20000.0
# cost for passive patients                            4500.0   6000.0   7500.0
# total cost for the month                            25000.0  25000.0  25000.0
#
#                                                          10  ...       15  \
# number of new patients                                250.0  ...    250.0
# number of old patients                               2250.0  ...   3500.0
# total number of patients                             2500.0  ...   3750.0
# number of completed blocks                              8.0  ...     12.0
# number of passive block                                 5.0  ...     10.0
# number of completed active blocks                       3.0  ...      2.0
# number of active patients not in a completed block    100.0  ...    150.0
# number of passive patients                              5.0  ...     10.0
# cost for active patients not in a block              6000.0  ...   8000.0
# cost for active blocks                              30000.0  ...  20000.0
# cost for passive patients                            7500.0  ...  15000.0
# total cost for the month                            25000.0  ...  25000.0
#
#                                                          16       17       18  \
# number of new patients                                250.0    250.0    250.0
# number of old patients                               3750.0   4000.0   4250.0
# total number of patients                             4000.0   4250.0   4500.0
# number of completed blocks                             13.0     14.0     15.0
# number of passive block                                10.0     11.0     12.0
# number of completed active blocks                       3.0      3.0      3.0
# number of active patients not in a completed block    100.0     50.0      0.0
# number of passive patients                             10.0     11.0     12.0
# cost for active patients not in a block              6000.0   4500.0      0.0
# cost for active blocks                              30000.0  30000.0  30000.0
# cost for passive patients                           15000.0  16500.0  18000.0
# total cost for the month                            25000.0  25000.0  25000.0
#
#                                                          19       20       21  \
# number of new patients                                250.0    250.0    250.0
# number of old patients                               4500.0   4750.0   5000.0
# total number of patients                             4750.0   5000.0   5250.0
# number of completed blocks                             15.0     16.0     17.0
# number of passive block                                13.0     14.0     15.0
# number of completed active blocks                       2.0      2.0      2.0
# number of active patients not in a completed block    250.0    200.0    150.0
# number of passive patients                             13.0     14.0     15.0
# cost for active patients not in a block             10000.0   9000.0   8000.0
# cost for active blocks                              20000.0  20000.0  20000.0
# cost for passive patients                           19500.0  21000.0  22500.0
# total cost for the month                            25000.0  25000.0  25000.0
#
#                                                          22       23       24
# number of new patients                                250.0    250.0    250.0
# number of old patients                               5250.0   5500.0   5750.0
# total number of patients                             5500.0   5750.0   6000.0
# number of completed blocks                             18.0     19.0     20.0
# number of passive block                                15.0     16.0     17.0
# number of completed active blocks                       3.0      3.0      3.0
# number of active patients not in a completed block    100.0     50.0      0.0
# number of passive patients                             15.0     16.0     17.0
# cost for active patients not in a block              6000.0   4500.0      0.0
# cost for active blocks                              30000.0  30000.0  30000.0
# cost for passive patients                           22500.0  24000.0  25500.0
# total cost for the month                            25000.0  25000.0  25000.0
#
# [12 rows x 24 columns]

# %%
file_name = 'Veeva_EDC_price_24Months_6000Patients.xlsx'
df.to_excel(file_name)
